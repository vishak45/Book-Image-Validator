# %%
import tensorflow as tf

IMG_SIZE = (224, 224)
BATCH_SIZE = 32

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    "images/train",
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    label_mode="binary"
)

val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    "images/val",
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    label_mode="binary"
)

print("success")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 6
#       3 IMG_SIZE = (224, 224)
#       4 BATCH_SIZE = 32
# ----> 6 train_ds = tf.keras.preprocessing.image_dataset_from_directory(
#       7     "images/train",
#       8     image_size=IMG_SIZE,
#       9     batch_size=BATCH_SIZE,
#      10     label_mode="binary"
#      11 )
#      13 val_ds = tf.keras.preprocessing.image_dataset_from_directory(
#      14     "images/val",
#      15     image_size=IMG_SIZE,
#      16     batch_size=BATCH_SIZE,
#      17     label_mode="binary"
#      18 )
#      20 print("success")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\keras\src\utils\image_dataset_utils.py:265, in image_dataset_from_directory(directory, labels, label_mode, class_names, color_mode, batch_size, image_size, shuffle, seed, validation_split, subset, interpolation, follow_links, crop_to_aspect_ratio, pad_to_aspect_ratio, data_format, format, verbose)
#     263 if seed is None:
#     264     seed = np.random.randint(1e6)
# --> 265 image_paths, labels, class_names = dataset_utils.index_directory(
#     266     directory,
#     267     labels,
#     268     formats=ALLOWLIST_FORMATS,
#     269     class_names=class_names,
#     270     shuffle=shuffle,
#     271     seed=seed,
#     272     follow_links=follow_links,
#     273     verbose=verbose,
#     274 )
#     276 if label_mode == "binary" and len(class_names) != 2:
#     277     raise ValueError(
#     278         'When passing `label_mode="binary"`, there must be exactly 2 '
#     279         f"class_names. Received: class_names={class_names}"
#     280     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\keras\src\utils\dataset_utils.py:743, in index_directory(directory, labels, formats, class_names, shuffle, seed, follow_links, verbose)
#     741 if labels == "inferred":
#     742     subdirs = []
# --> 743     for subdir in sorted(os_module.listdir(directory)):
#     744         if path_module.isdir(path_module.join(directory, subdir)):
#     745             if not subdir.startswith("."):
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'images/train'
